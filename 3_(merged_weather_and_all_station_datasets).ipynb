# %%
#importing necessary libraries
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline 

from sklearn.preprocessing import LabelEncoder

import warnings
warnings.filterwarnings("ignore")

# %%
#reading train dataframe
train_df = pd.read_csv('train_target.csv')

# %%
#reading weather dataframe
weather_df = pd.read_csv('weather_2004_v2.csv')

# %%
#reading allstation weather dataframe
allstation_df = pd.read_csv('AllStationsData_PHD.txt',sep = '|')

# %%
train_df.head()
# Out:
#     FlightNumber  DayOfWeek Origin Destination  Distance  \
# 0  SMF_ATL_37955          3    SMF         ATL      2092
# 1  VLD_ATL_48545          3    VLD         ATL       208
# 2  DTW_BOS_31626          3    DTW         BOS       632
# 3  MKE_BWI_39603          3    MKE         BWI       641
# 4  DFW_CLT_33648          3    DFW         CLT       936
#
#   ActualArrivalTimeStamp   ScheduledArrTime_c  FlightDelayStatus
# 0    2004-01-01 19:11:00  2004-01-01 19:11:00                  2
# 1    2004-01-01 14:55:00  2004-01-01 14:55:00                  2
# 2    2004-01-01 18:33:00  2004-01-01 16:57:00                  1
# 3    2004-01-01 15:25:00  2004-01-01 15:25:00                  2
# 4    2004-01-01 18:14:00  2004-01-01 18:14:00                  2

# %%
allstation_df.head()
# Out:
#    WeatherStationID AirportID  GroundHeight  StationHeight  BarometerHeight  \
# 0              3011       TEX             0              0                0
# 1              3012       SKX             0              0                0
# 2              3013       LAA          3683           3703             3675
# 3              3014       4SL             0           6909                0
# 4              3016       RIL          5503           5544             5506
#
#    Latitude  Longitude TimeZone
# 0     37.57    -107.55       +7
# 1     36.28    -105.40       +7
# 2     38.04    -102.41       +7
# 3     35.47    -107.14       +7
# 4     39.32    -107.44       +7

# %%
weather_df.head()
# Out:
#    WeatherStationID         SkyConditions  Visibility   DBT  \
# 0              3011         FEW075 BKN090       10.00  32.0
# 1              3011         BKN028 OVC033       10.00  21.0
# 2              3011         FEW025 OVC032        9.00  25.0
# 3              3011  FEW045 BKN060 OVC080       10.00  34.0
# 4              3011         BKN010 OVC017        1.75  25.0
#
#    RelativeHumidityPercent  WindSpeed  WindDirection  StationPressure  \
# 0                     40.0       15.0            160            30.05
# 1                     74.0        5.0             30            30.06
# 2                     75.0        4.0             30            30.06
# 3                     54.0       16.0            240            29.92
# 4                     85.0        0.0              0            29.95
#
#    HourlyPrecip    YearMonthDay_Time
# 0           0.0  2004-01-01 13:50:00
# 1           0.0  2004-01-01 19:10:00
# 2           0.0  2004-01-01 20:10:00
# 3           0.0  2004-01-02 04:10:00
# 4           0.0  2004-01-02 07:30:00

# %%
allstation_df.nunique()
# Out:
# WeatherStationID    1744
# AirportID           1744
# GroundHeight         720
# StationHeight        919
# BarometerHeight      730
# Latitude            1022
# Longitude           1362
# TimeZone              12
# dtype: int64

# %%
weather_df.nunique()
# Out:
# WeatherStationID             1447
# SkyConditions              247019
# Visibility                     71
# DBT                           170
# RelativeHumidityPercent        99
# WindSpeed                      69
# WindDirection                  82
# StationPressure              1006
# HourlyPrecip                  256
# YearMonthDay_Time          218044
# dtype: int64

# %%
print(train_df.shape)
print(allstation_df.shape)
print(weather_df.shape)
# Out:
# (7861, 8)
# (1744, 8)
# (6485177, 10)

# %%
#checking the datatypes to maintain consistency
def data(*args):
    for i in args:
        print(i.dtypes)
        print()
        
data(train_df,allstation_df,weather_df)
# Out:
# FlightNumber              object
# DayOfWeek                  int64
# Origin                    object
# Destination               object
# Distance                   int64
# ActualArrivalTimeStamp    object
# ScheduledArrTime_c        object
# FlightDelayStatus          int64
# dtype: object
#
# WeatherStationID      int64
# AirportID            object
# GroundHeight          int64
# StationHeight         int64
# BarometerHeight       int64
# Latitude            float64
# Longitude           float64
# TimeZone             object
# dtype: object
#
# WeatherStationID             int64
# SkyConditions               object
# Visibility                 float64
# DBT                        float64
# RelativeHumidityPercent    float64
# WindSpeed                  float64
# WindDirection                int64
# StationPressure            float64
# HourlyPrecip               float64
# YearMonthDay_Time           object
# dtype: object

# %%
#defining a function to check null values of all dataframes at single run
def data(*args):
    for i in args:
        print(i.isna().sum())
        print()
        
data(train_df,allstation_df,weather_df)
# Out:
# FlightNumber              0
# DayOfWeek                 0
# Origin                    0
# Destination               0
# Distance                  0
# ActualArrivalTimeStamp    0
# ScheduledArrTime_c        0
# FlightDelayStatus         0
# dtype: int64
#
# WeatherStationID    0
# AirportID           0
# GroundHeight        0
# StationHeight       0
# BarometerHeight     0
# Latitude            0
# Longitude           0
# TimeZone            0
# dtype: int64
#
# WeatherStationID           0
# SkyConditions              0
# Visibility                 0
# DBT                        0
# RelativeHumidityPercent    0
# WindSpeed                  0
# WindDirection              0
# StationPressure            0
# HourlyPrecip               0
# YearMonthDay_Time          0
# dtype: int64

# %%
# merged weather and all station data frames
weather_2004 = pd.merge(weather_df, allstation_df,how = 'left',on = 'WeatherStationID')

# %%
weather_2004.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6485177 entries, 0 to 6485176
# Data columns (total 17 columns):
#  #   Column                   Dtype
# ---  ------                   -----
#  0   WeatherStationID         int64
#  1   SkyConditions            object
#  2   Visibility               float64
#  3   DBT                      float64
#  4   RelativeHumidityPercent  float64
#  5   WindSpeed                float64
#  6   WindDirection            int64
#  7   StationPressure          float64
#  8   HourlyPrecip             float64
#  9   YearMonthDay_Time        object
#  10  AirportID                object
#  11  GroundHeight             float64
#  12  StationHeight            float64
#  13  BarometerHeight          float64
#  14  Latitude                 float64
#  15  Longitude                float64
#  16  TimeZone                 object
# dtypes: float64(11), int64(2), object(4)
# memory usage: 890.6+ MB

# %%
weather_2004.head()
# Out:
#    WeatherStationID         SkyConditions  Visibility   DBT  \
# 0              3011         FEW075 BKN090       10.00  32.0
# 1              3011         BKN028 OVC033       10.00  21.0
# 2              3011         FEW025 OVC032        9.00  25.0
# 3              3011  FEW045 BKN060 OVC080       10.00  34.0
# 4              3011         BKN010 OVC017        1.75  25.0
#
#    RelativeHumidityPercent  WindSpeed  WindDirection  StationPressure  \
# 0                     40.0       15.0            160            30.05
# 1                     74.0        5.0             30            30.06
# 2                     75.0        4.0             30            30.06
# 3                     54.0       16.0            240            29.92
# 4                     85.0        0.0              0            29.95
#
#    HourlyPrecip    YearMonthDay_Time AirportID  GroundHeight  StationHeight  \
# 0           0.0  2004-01-01 13:50:00       TEX           0.0            0.0
# 1           0.0  2004-01-01 19:10:00       TEX           0.0            0.0
# 2           0.0  2004-01-01 20:10:00       TEX           0.0            0.0
# 3           0.0  2004-01-02 04:10:00       TEX           0.0            0.0
# 4           0.0  2004-01-02 07:30:00       TEX           0.0            0.0
#
#    BarometerHeight  Latitude  Longitude TimeZone
# 0              0.0     37.57    -107.55       +7
# 1              0.0     37.57    -107.55       +7
# 2              0.0     37.57    -107.55       +7
# 3              0.0     37.57    -107.55       +7
# 4              0.0     37.57    -107.55       +7

# %%
weather_2004.shape
# Out:
# (6485177, 17)

# %%
weather_2004.dtypes
# Out:
# WeatherStationID             int64
# SkyConditions               object
# Visibility                 float64
# DBT                        float64
# RelativeHumidityPercent    float64
# WindSpeed                  float64
# WindDirection                int64
# StationPressure            float64
# HourlyPrecip               float64
# YearMonthDay_Time           object
# AirportID                   object
# GroundHeight               float64
# StationHeight              float64
# BarometerHeight            float64
# Latitude                   float64
# Longitude                  float64
# TimeZone                    object
# dtype: object

# %%
# Corelation plot 
corr = weather_2004.corr()
corr.style.background_gradient(cmap='flare').set_precision(2)
# Out:
# <style type="text/css">
# #T_b1e00_row0_col0, #T_b1e00_row1_col1, #T_b1e00_row2_col2, #T_b1e00_row3_col3, #T_b1e00_row4_col4, #T_b1e00_row5_col5, #T_b1e00_row6_col6, #T_b1e00_row7_col7, #T_b1e00_row8_col8, #T_b1e00_row8_col10, #T_b1e00_row9_col9, #T_b1e00_row10_col8, #T_b1e00_row10_col10, #T_b1e00_row11_col11, #T_b1e00_row12_col12 {
#   background-color: #4b2362;
#   color: #f1f1f1;
# }
# #T_b1e00_row0_col1, #T_b1e00_row12_col1 {
#   background-color: #eb9c75;
#   color: #000000;
# }
# #T_b1e00_row0_col2, #T_b1e00_row11_col6, #T_b1e00_row11_col9 {
#   background-color: #d64f5f;
#   color: #f1f1f1;
# }
# #T_b1e00_row0_col3, #T_b1e00_row1_col4 {
#   background-color: #e77c63;
#   color: #f1f1f1;
# }
# #T_b1e00_row0_col4, #T_b1e00_row2_col5 {
#   background-color: #ea8f6c;
#   color: #f1f1f1;
# }
# #T_b1e00_row0_col5 {
#   background-color: #ea946f;
#   color: #f1f1f1;
# }
# #T_b1e00_row0_col6, #T_b1e00_row4_col11 {
#   background-color: #da555d;
#   color: #f1f1f1;
# }
# #T_b1e00_row0_col7, #T_b1e00_row8_col3 {
#   background-color: #eca77b;
#   color: #000000;
# }
# #T_b1e00_row0_col8, #T_b1e00_row0_col10, #T_b1e00_row4_col8, #T_b1e00_row4_col10 {
#   background-color: #ce4763;
#   color: #f1f1f1;
# }
# #T_b1e00_row0_col9, #T_b1e00_row4_col9 {
#   background-color: #d04962;
#   color: #f1f1f1;
# }
# #T_b1e00_row0_col11, #T_b1e00_row1_col12, #T_b1e00_row9_col11 {
#   background-color: #de5c5c;
#   color: #f1f1f1;
# }
# #T_b1e00_row0_col12, #T_b1e00_row2_col8, #T_b1e00_row2_col10, #T_b1e00_row7_col12, #T_b1e00_row8_col11, #T_b1e00_row10_col11 {
#   background-color: #dc585c;
#   color: #f1f1f1;
# }
# #T_b1e00_row1_col0, #T_b1e00_row5_col3, #T_b1e00_row11_col1 {
#   background-color: #ec9f76;
#   color: #000000;
# }
# #T_b1e00_row1_col2, #T_b1e00_row7_col2 {
#   background-color: #dc575c;
#   color: #f1f1f1;
# }
# #T_b1e00_row1_col3, #T_b1e00_row7_col5, #T_b1e00_row12_col4 {
#   background-color: #ea8e6c;
#   color: #f1f1f1;
# }
# #T_b1e00_row1_col5, #T_b1e00_row3_col2 {
#   background-color: #e98667;
#   color: #f1f1f1;
# }
# #T_b1e00_row1_col6, #T_b1e00_row3_col12 {
#   background-color: #d44d60;
#   color: #f1f1f1;
# }
# #T_b1e00_row1_col7, #T_b1e00_row2_col3, #T_b1e00_row2_col11, #T_b1e00_row3_col1, #T_b1e00_row3_col4, #T_b1e00_row3_col5, #T_b1e00_row6_col0, #T_b1e00_row6_col8, #T_b1e00_row6_col9, #T_b1e00_row6_col10, #T_b1e00_row8_col6, #T_b1e00_row10_col6, #T_b1e00_row11_col2, #T_b1e00_row11_col12 {
#   background-color: #edb081;
#   color: #000000;
# }
# #T_b1e00_row1_col8, #T_b1e00_row1_col10, #T_b1e00_row5_col9, #T_b1e00_row6_col12 {
#   background-color: #d34c60;
#   color: #f1f1f1;
# }
# #T_b1e00_row1_col9, #T_b1e00_row7_col6 {
#   background-color: #d54e5f;
#   color: #f1f1f1;
# }
# #T_b1e00_row1_col11, #T_b1e00_row2_col9, #T_b1e00_row5_col2, #T_b1e00_row6_col3 {
#   background-color: #de5d5c;
#   color: #f1f1f1;
# }
# #T_b1e00_row2_col0 {
#   background-color: #e98b6a;
#   color: #f1f1f1;
# }
# #T_b1e00_row2_col1 {
#   background-color: #eb9872;
#   color: #000000;
# }
# #T_b1e00_row2_col4 {
#   background-color: #e77a62;
#   color: #f1f1f1;
# }
# #T_b1e00_row2_col6 {
#   background-color: #cf4862;
#   color: #f1f1f1;
# }
# #T_b1e00_row2_col7, #T_b1e00_row7_col1, #T_b1e00_row12_col7 {
#   background-color: #eca379;
#   color: #000000;
# }
# #T_b1e00_row2_col12 {
#   background-color: #c34167;
#   color: #f1f1f1;
# }
# #T_b1e00_row3_col0, #T_b1e00_row6_col1, #T_b1e00_row7_col0 {
#   background-color: #eb9e76;
#   color: #000000;
# }
# #T_b1e00_row3_col6 {
#   background-color: #c14068;
#   color: #f1f1f1;
# }
# #T_b1e00_row3_col7 {
#   background-color: #e98d6b;
#   color: #f1f1f1;
# }
# #T_b1e00_row3_col8, #T_b1e00_row3_col10 {
#   background-color: #e3685c;
#   color: #f1f1f1;
# }
# #T_b1e00_row3_col9 {
#   background-color: #e46e5e;
#   color: #f1f1f1;
# }
# #T_b1e00_row3_col11, #T_b1e00_row4_col2, #T_b1e00_row4_col6 {
#   background-color: #db565d;
#   color: #f1f1f1;
# }
# #T_b1e00_row4_col0, #T_b1e00_row11_col7, #T_b1e00_row12_col11 {
#   background-color: #edaf80;
#   color: #000000;
# }
# #T_b1e00_row4_col1, #T_b1e00_row5_col1 {
#   background-color: #eb9771;
#   color: #f1f1f1;
# }
# #T_b1e00_row4_col3 {
#   background-color: #edac7e;
#   color: #000000;
# }
# #T_b1e00_row4_col5 {
#   background-color: #bb3f6a;
#   color: #f1f1f1;
# }
# #T_b1e00_row4_col7 {
#   background-color: #eca077;
#   color: #000000;
# }
# #T_b1e00_row4_col12, #T_b1e00_row7_col3 {
#   background-color: #e2665c;
#   color: #f1f1f1;
# }
# #T_b1e00_row5_col0, #T_b1e00_row8_col7, #T_b1e00_row9_col3, #T_b1e00_row10_col7 {
#   background-color: #eca87c;
#   color: #000000;
# }
# #T_b1e00_row5_col4 {
#   background-color: #b53d6b;
#   color: #f1f1f1;
# }
# #T_b1e00_row5_col6 {
#   background-color: #d8525e;
#   color: #f1f1f1;
# }
# #T_b1e00_row5_col7, #T_b1e00_row6_col7, #T_b1e00_row9_col6 {
#   background-color: #edab7e;
#   color: #000000;
# }
# #T_b1e00_row5_col8, #T_b1e00_row5_col10 {
#   background-color: #d14a61;
#   color: #f1f1f1;
# }
# #T_b1e00_row5_col11 {
#   background-color: #d9535d;
#   color: #f1f1f1;
# }
# #T_b1e00_row5_col12 {
#   background-color: #e1625c;
#   color: #f1f1f1;
# }
# #T_b1e00_row6_col2 {
#   background-color: #da545d;
#   color: #f1f1f1;
# }
# #T_b1e00_row6_col4 {
#   background-color: #ea906d;
#   color: #f1f1f1;
# }
# #T_b1e00_row6_col5, #T_b1e00_row12_col5 {
#   background-color: #ea9570;
#   color: #f1f1f1;
# }
# #T_b1e00_row6_col11, #T_b1e00_row12_col8, #T_b1e00_row12_col10 {
#   background-color: #e05f5c;
#   color: #f1f1f1;
# }
# #T_b1e00_row7_col4 {
#   background-color: #e67961;
#   color: #f1f1f1;
# }
# #T_b1e00_row7_col8, #T_b1e00_row7_col10 {
#   background-color: #d44c60;
#   color: #f1f1f1;
# }
# #T_b1e00_row7_col9 {
#   background-color: #d7505e;
#   color: #f1f1f1;
# }
# #T_b1e00_row7_col11 {
#   background-color: #df5f5c;
#   color: #f1f1f1;
# }
# #T_b1e00_row8_col0, #T_b1e00_row10_col0 {
#   background-color: #ea936f;
#   color: #f1f1f1;
# }
# #T_b1e00_row8_col1, #T_b1e00_row9_col1, #T_b1e00_row10_col1 {
#   background-color: #eb9a73;
#   color: #000000;
# }
# #T_b1e00_row8_col2, #T_b1e00_row10_col2 {
#   background-color: #e36a5d;
#   color: #f1f1f1;
# }
# #T_b1e00_row8_col4, #T_b1e00_row8_col12, #T_b1e00_row10_col4, #T_b1e00_row10_col12, #T_b1e00_row11_col3 {
#   background-color: #e67560;
#   color: #f1f1f1;
# }
# #T_b1e00_row8_col5, #T_b1e00_row9_col5, #T_b1e00_row10_col5 {
#   background-color: #e88567;
#   color: #f1f1f1;
# }
# #T_b1e00_row8_col9, #T_b1e00_row9_col8, #T_b1e00_row9_col10, #T_b1e00_row10_col9 {
#   background-color: #522564;
#   color: #f1f1f1;
# }
# #T_b1e00_row9_col0 {
#   background-color: #ea926e;
#   color: #f1f1f1;
# }
# #T_b1e00_row9_col2 {
#   background-color: #e36b5d;
#   color: #f1f1f1;
# }
# #T_b1e00_row9_col4 {
#   background-color: #e5745f;
#   color: #f1f1f1;
# }
# #T_b1e00_row9_col7 {
#   background-color: #ecaa7d;
#   color: #000000;
# }
# #T_b1e00_row9_col12 {
#   background-color: #e67660;
#   color: #f1f1f1;
# }
# #T_b1e00_row10_col3 {
#   background-color: #eca67b;
#   color: #000000;
# }
# #T_b1e00_row11_col0 {
#   background-color: #eca178;
#   color: #000000;
# }
# #T_b1e00_row11_col4 {
#   background-color: #e67861;
#   color: #f1f1f1;
# }
# #T_b1e00_row11_col5 {
#   background-color: #e88064;
#   color: #f1f1f1;
# }
# #T_b1e00_row11_col8, #T_b1e00_row11_col10 {
#   background-color: #d24a61;
#   color: #f1f1f1;
# }
# #T_b1e00_row12_col0 {
#   background-color: #eb9973;
#   color: #000000;
# }
# #T_b1e00_row12_col2 {
#   background-color: #c24167;
#   color: #f1f1f1;
# }
# #T_b1e00_row12_col3 {
#   background-color: #e2675c;
#   color: #f1f1f1;
# }
# #T_b1e00_row12_col6 {
#   background-color: #c64366;
#   color: #f1f1f1;
# }
# #T_b1e00_row12_col9 {
#   background-color: #e1645c;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_b1e00_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >WeatherStationID</th>
#       <th class="col_heading level0 col1" >Visibility</th>
#       <th class="col_heading level0 col2" >DBT</th>
#       <th class="col_heading level0 col3" >RelativeHumidityPercent</th>
#       <th class="col_heading level0 col4" >WindSpeed</th>
#       <th class="col_heading level0 col5" >WindDirection</th>
#       <th class="col_heading level0 col6" >StationPressure</th>
#       <th class="col_heading level0 col7" >HourlyPrecip</th>
#       <th class="col_heading level0 col8" >GroundHeight</th>
#       <th class="col_heading level0 col9" >StationHeight</th>
#       <th class="col_heading level0 col10" >BarometerHeigh

# %% [raw]
# Station Height is the vertical distance above mean sea level that is adopted as the reference datum level for all current measurements of atmospheric pressure at the station.

# %%
weather_2004.drop(['GroundHeight','BarometerHeight'],axis = 1,inplace = True)

# %%
weather_2004.head()
# Out:
#    WeatherStationID         SkyConditions  Visibility   DBT  \
# 0              3011         FEW075 BKN090       10.00  32.0
# 1              3011         BKN028 OVC033       10.00  21.0
# 2              3011         FEW025 OVC032        9.00  25.0
# 3              3011  FEW045 BKN060 OVC080       10.00  34.0
# 4              3011         BKN010 OVC017        1.75  25.0
#
#    RelativeHumidityPercent  WindSpeed  WindDirection  StationPressure  \
# 0                     40.0       15.0            160            30.05
# 1                     74.0        5.0             30            30.06
# 2                     75.0        4.0             30            30.06
# 3                     54.0       16.0            240            29.92
# 4                     85.0        0.0              0            29.95
#
#    HourlyPrecip    YearMonthDay_Time AirportID  StationHeight  Latitude  \
# 0           0.0  2004-01-01 13:50:00       TEX            0.0     37.57
# 1           0.0  2004-01-01 19:10:00       TEX            0.0     37.57
# 2           0.0  2004-01-01 20:10:00       TEX            0.0     37.57
# 3           0.0  2004-01-02 04:10:00       TEX            0.0     37.57
# 4           0.0  2004-01-02 07:30:00       TEX            0.0     37.57
#
#    Longitude TimeZone
# 0    -107.55       +7
# 1    -107.55       +7
# 2    -107.55       +7
# 3    -107.55       +7
# 4    -107.55       +7

# %%
weather_2004.tail()
# Out:
#          WeatherStationID SkyConditions  Visibility   DBT  \
# 6485172             94999           CLR        10.0  36.0
# 6485173             94999           CLR        10.0  37.0
# 6485174             94999           CLR        10.0  37.0
# 6485175             94999           CLR        10.0  37.0
# 6485176             94999           CLR        10.0  34.0
#
#          RelativeHumidityPercent  WindSpeed  WindDirection  StationPressure  \
# 6485172                     64.0        9.0            200            29.84
# 6485173                     62.0        6.0            230            29.82
# 6485174                     57.0        8.0            220            29.80
# 6485175                     62.0        7.0            200            29.79
# 6485176                     64.0        4.0            200            29.79
#
#          HourlyPrecip    YearMonthDay_Time AirportID  StationHeight  Latitude  \
# 6485172           0.0  2004-11-30 12:55:00       AIT         1204.0     46.33
# 6485173           0.0  2004-11-30 13:55:00       AIT         1204.0     46.33
# 6485174           0.0  2004-11-30 14:55:00       AIT         1204.0     46.33
# 6485175           0.0  2004-11-30 15:55:00       AIT         1204.0     46.33
# 6485176           0.0  2004-11-30 16:55:00       AIT         1204.0     46.33
#
#          Longitude TimeZone
# 6485172     -93.41       +6
# 6485173     -93.41       +6
# 6485174     -93.41       +6
# 6485175     -93.41       +6
# 6485176     -93.41       +6

# %%
weather_2004.dtypes
# Out:
# WeatherStationID             int64
# SkyConditions               object
# Visibility                 float64
# DBT                        float64
# RelativeHumidityPercent    float64
# WindSpeed                  float64
# WindDirection                int64
# StationPressure            float64
# HourlyPrecip               float64
# YearMonthDay_Time           object
# AirportID                   object
# StationHeight              float64
# Latitude                   float64
# Longitude                  float64
# TimeZone                    object
# dtype: object

# %%
weather_2004.shape
# Out:
# (6485177, 15)

# %%
weather_2004.isna().sum()
# Out:
# WeatherStationID             0
# SkyConditions                0
# Visibility                   0
# DBT                          0
# RelativeHumidityPercent      0
# WindSpeed                    0
# WindDirection                0
# StationPressure              0
# HourlyPrecip                 0
# YearMonthDay_Time            0
# AirportID                  928
# StationHeight              928
# Latitude                   928
# Longitude                  928
# TimeZone                   928
# dtype: int64

# %%
weather_2004['TimeZone'].nunique()
# Out:
# 11

# %%
weather_2004['TimeZone'].unique()
# Out:
# array(['+7', '+6', '+8', '+5', '+4', '+10', '+9', 'Yukon Standard',
#        'Bering Standard', '-10', 'Alaska-Hawaii', nan], dtype=object)

# %%
#creating instance of labelencoder
labelencoder = LabelEncoder()
# Assigning numerical values and storing
weather_2004['TimeZone'] = labelencoder.fit_transform(weather_2004['TimeZone'])

# %%
weather_2004['TimeZone'].unique()
# Out:
# array([ 4,  3,  5,  2,  1,  0,  6, 10,  9,  7,  8, 11])

# %%
# Final consolidated weather data
weather_2004.head()
# Out:
#    WeatherStationID         SkyConditions  Visibility   DBT  \
# 0              3011         FEW075 BKN090       10.00  32.0
# 1              3011         BKN028 OVC033       10.00  21.0
# 2              3011         FEW025 OVC032        9.00  25.0
# 3              3011  FEW045 BKN060 OVC080       10.00  34.0
# 4              3011         BKN010 OVC017        1.75  25.0
#
#    RelativeHumidityPercent  WindSpeed  WindDirection  StationPressure  \
# 0                     40.0       15.0            160            30.05
# 1                     74.0        5.0             30            30.06
# 2                     75.0        4.0             30            30.06
# 3                     54.0       16.0            240            29.92
# 4                     85.0        0.0              0            29.95
#
#    HourlyPrecip    YearMonthDay_Time AirportID  StationHeight  Latitude  \
# 0           0.0  2004-01-01 13:50:00       TEX            0.0     37.57
# 1           0.0  2004-01-01 19:10:00       TEX            0.0     37.57
# 2           0.0  2004-01-01 20:10:00       TEX            0.0     37.57
# 3           0.0  2004-01-02 04:10:00       TEX            0.0     37.57
# 4           0.0  2004-01-02 07:30:00       TEX            0.0     37.57
#
#    Longitude  TimeZone
# 0    -107.55         4
# 1    -107.55         4
# 2    -107.55         4
# 3    -107.55         4
# 4    -107.55         4

# %%
weather_2004['SkyConditions'].nunique()
# Out:
# 247019

# %%
#saving the dataset in csv format
weather_2004.to_csv('final_weather_data.csv',index_label = False)
