# %%
#importing necessary libraries
import numpy as np
import pandas as pd

from sklearn.preprocessing import LabelEncoder

# %%
#reading train data
train_df = pd.read_csv('Train.csv')

# %%
train_df.head()
# Out:
#     FlightNumber  Year  Month  DayofMonth  DayOfWeek  ScheduledDepTime  \
# 0  BOS_CLE_29089  2004      9          20          1              1000
# 1  CLE_ATL_44346  2004     11          19          5              1440
# 2  SNA_LAS_44378  2004      5           4          2              1800
# 3  CLT_TPA_51502  2004      7           6          2              1400
# 4  MSP_ORD_44884  2004      9          23          4               830
#
#    ScheduledArrTime  ScheduledTravelTime Origin Destination  Distance  \
# 0              1154                  114    BOS         CLE       563
# 1              1634                  114    CLE         ATL       554
# 2              1902                   62    SNA         LAS       226
# 3              1533                   93    CLT         TPA       508
# 4               946                   76    MSP         ORD       334
#
#   ActualArrivalTimeStamp
# 0         20/09/04 11:54
# 1         19/11/04 18:55
# 2         04/05/04 19:02
# 3         06/07/04 15:33
# 4         23/09/04 09:46

# %%
# train dataframe info
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7861 entries, 0 to 7860
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   FlightNumber            7861 non-null   object
#  1   Year                    7861 non-null   int64
#  2   Month                   7861 non-null   int64
#  3   DayofMonth              7861 non-null   int64
#  4   DayOfWeek               7861 non-null   int64
#  5   ScheduledDepTime        7861 non-null   int64
#  6   ScheduledArrTime        7861 non-null   int64
#  7   ScheduledTravelTime     7861 non-null   int64
#  8   Origin                  7861 non-null   object
#  9   Destination             7861 non-null   object
#  10  Distance                7861 non-null   int64
#  11  ActualArrivalTimeStamp  7861 non-null   object
# dtypes: int64(8), object(4)
# memory usage: 737.1+ KB

# %%
train_df.isnull().sum()
# Out:
# FlightNumber              0
# Year                      0
# Month                     0
# DayofMonth                0
# DayOfWeek                 0
# ScheduledDepTime          0
# ScheduledArrTime          0
# ScheduledTravelTime       0
# Origin                    0
# Destination               0
# Distance                  0
# ActualArrivalTimeStamp    0
# dtype: int64

# %%
#sorting values w.r.t month, day and destination
train_df.sort_values(['Month','DayofMonth','Destination'], inplace = True, ignore_index = True)

# %%
train_df.shape
# Out:
# (7861, 12)

# %%
train_df.dtypes
# Out:
# FlightNumber              object
# Year                       int64
# Month                      int64
# DayofMonth                 int64
# DayOfWeek                  int64
# ScheduledDepTime           int64
# ScheduledArrTime           int64
# ScheduledTravelTime        int64
# Origin                    object
# Destination               object
# Distance                   int64
# ActualArrivalTimeStamp    object
# dtype: object

# %%
# converting ActualArrivalTimeStamp col to datetime
actual_arrival_time_stamp = train_df['ActualArrivalTimeStamp'].astype(str)
train_df['ActualArrivalTimeStamp'] = pd.to_datetime(actual_arrival_time_stamp, dayfirst=True)

# %%
train_df.head()
# Out:
#     FlightNumber  Year  Month  DayofMonth  DayOfWeek  ScheduledDepTime  \
# 0  SMF_ATL_37955  2004      1           1          4              1150
# 1  VLD_ATL_48545  2004      1           1          4              1329
# 2  DTW_BOS_31626  2004      1           1          4              1507
# 3  MKE_BWI_39603  2004      1           1          4              1240
# 4  DFW_CLT_33648  2004      1           1          4              1456
#
#    ScheduledArrTime  ScheduledTravelTime Origin Destination  Distance  \
# 0              1911                  261    SMF         ATL      2092
# 1              1455                   86    VLD         ATL       208
# 2              1657                  110    DTW         BOS       632
# 3              1525                  105    MKE         BWI       641
# 4              1814                  138    DFW         CLT       936
#
#   ActualArrivalTimeStamp
# 0    2004-01-01 19:11:00
# 1    2004-01-01 14:55:00
# 2    2004-01-01 18:33:00
# 3    2004-01-01 15:25:00
# 4    2004-01-01 18:14:00

# %%
train_df.dtypes
# Out:
# FlightNumber                      object
# Year                               int64
# Month                              int64
# DayofMonth                         int64
# DayOfWeek                          int64
# ScheduledDepTime                   int64
# ScheduledArrTime                   int64
# ScheduledTravelTime                int64
# Origin                            object
# Destination                       object
# Distance                           int64
# ActualArrivalTimeStamp    datetime64[ns]
# dtype: object

# %%
# converting respective columns to be converted to datetime to string, and then using zfill method
train_df['Month'] = train_df['Month'].astype(str)
train_df['DayofMonth'] = train_df['DayofMonth'].astype(str)
train_df['ScheduledArrTime'] = train_df['ScheduledArrTime'].astype(str)

train_df['Month'] = train_df['Month'].str.zfill(2)
train_df['DayofMonth'] = train_df['DayofMonth'].str.zfill(2)
train_df['ScheduledArrTime'] = train_df['ScheduledArrTime'].str.zfill(4)

# %%
train_df.head()
# Out:
#     FlightNumber  Year Month DayofMonth  DayOfWeek  ScheduledDepTime  \
# 0  SMF_ATL_37955  2004    01         01          4              1150
# 1  VLD_ATL_48545  2004    01         01          4              1329
# 2  DTW_BOS_31626  2004    01         01          4              1507
# 3  MKE_BWI_39603  2004    01         01          4              1240
# 4  DFW_CLT_33648  2004    01         01          4              1456
#
#   ScheduledArrTime  ScheduledTravelTime Origin Destination  Distance  \
# 0             1911                  261    SMF         ATL      2092
# 1             1455                   86    VLD         ATL       208
# 2             1657                  110    DTW         BOS       632
# 3             1525                  105    MKE         BWI       641
# 4             1814                  138    DFW         CLT       936
#
#   ActualArrivalTimeStamp
# 0    2004-01-01 19:11:00
# 1    2004-01-01 14:55:00
# 2    2004-01-01 18:33:00
# 3    2004-01-01 15:25:00
# 4    2004-01-01 18:14:00

# %%
# Deriving new column using date and time columns
train_df['ScheduledArrTime_c'] = train_df['Year'].astype(str) + train_df['Month'] + train_df['DayofMonth'] + train_df['ScheduledArrTime']

# %%
train_df['ScheduledArrTime_c'] = pd.to_datetime(train_df['ScheduledArrTime_c'],format = '%Y%m%d%H%M')

# %%
pd.options.display.max_rows = 200
train_df.head()
# Out:
#     FlightNumber  Year Month DayofMonth  DayOfWeek  ScheduledDepTime  \
# 0  SMF_ATL_37955  2004    01         01          4              1150
# 1  VLD_ATL_48545  2004    01         01          4              1329
# 2  DTW_BOS_31626  2004    01         01          4              1507
# 3  MKE_BWI_39603  2004    01         01          4              1240
# 4  DFW_CLT_33648  2004    01         01          4              1456
#
#   ScheduledArrTime  ScheduledTravelTime Origin Destination  Distance  \
# 0             1911                  261    SMF         ATL      2092
# 1             1455                   86    VLD         ATL       208
# 2             1657                  110    DTW         BOS       632
# 3             1525                  105    MKE         BWI       641
# 4             1814                  138    DFW         CLT       936
#
#   ActualArrivalTimeStamp  ScheduledArrTime_c
# 0    2004-01-01 19:11:00 2004-01-01 19:11:00
# 1    2004-01-01 14:55:00 2004-01-01 14:55:00
# 2    2004-01-01 18:33:00 2004-01-01 16:57:00
# 3    2004-01-01 15:25:00 2004-01-01 15:25:00
# 4    2004-01-01 18:14:00 2004-01-01 18:14:00

# %%
# converting derived column to datetime format
train_df['ScheduledArrTime_c'] = pd.to_datetime(train_df['ScheduledArrTime_c'],format = '%Y%m%d%H%M')

# %%
train_df.head()
# Out:
#     FlightNumber  Year Month DayofMonth  DayOfWeek  ScheduledDepTime  \
# 0  SMF_ATL_37955  2004    01         01          4              1150
# 1  VLD_ATL_48545  2004    01         01          4              1329
# 2  DTW_BOS_31626  2004    01         01          4              1507
# 3  MKE_BWI_39603  2004    01         01          4              1240
# 4  DFW_CLT_33648  2004    01         01          4              1456
#
#   ScheduledArrTime  ScheduledTravelTime Origin Destination  Distance  \
# 0             1911                  261    SMF         ATL      2092
# 1             1455                   86    VLD         ATL       208
# 2             1657                  110    DTW         BOS       632
# 3             1525                  105    MKE         BWI       641
# 4             1814                  138    DFW         CLT       936
#
#   ActualArrivalTimeStamp  ScheduledArrTime_c
# 0    2004-01-01 19:11:00 2004-01-01 19:11:00
# 1    2004-01-01 14:55:00 2004-01-01 14:55:00
# 2    2004-01-01 18:33:00 2004-01-01 16:57:00
# 3    2004-01-01 15:25:00 2004-01-01 15:25:00
# 4    2004-01-01 18:14:00 2004-01-01 18:14:00

# %%
# subtracting to obtain total time in datetime format
train_df['FlightDelayinmin'] = train_df['ActualArrivalTimeStamp'] - train_df['ScheduledArrTime_c']

# %%
train_df.head()
# Out:
#     FlightNumber  Year Month DayofMonth  DayOfWeek  ScheduledDepTime  \
# 0  SMF_ATL_37955  2004    01         01          4              1150
# 1  VLD_ATL_48545  2004    01         01          4              1329
# 2  DTW_BOS_31626  2004    01         01          4              1507
# 3  MKE_BWI_39603  2004    01         01          4              1240
# 4  DFW_CLT_33648  2004    01         01          4              1456
#
#   ScheduledArrTime  ScheduledTravelTime Origin Destination  Distance  \
# 0             1911                  261    SMF         ATL      2092
# 1             1455                   86    VLD         ATL       208
# 2             1657                  110    DTW         BOS       632
# 3             1525                  105    MKE         BWI       641
# 4             1814                  138    DFW         CLT       936
#
#   ActualArrivalTimeStamp  ScheduledArrTime_c FlightDelayinmin
# 0    2004-01-01 19:11:00 2004-01-01 19:11:00  0 days 00:00:00
# 1    2004-01-01 14:55:00 2004-01-01 14:55:00  0 days 00:00:00
# 2    2004-01-01 18:33:00 2004-01-01 16:57:00  0 days 01:36:00
# 3    2004-01-01 15:25:00 2004-01-01 15:25:00  0 days 00:00:00
# 4    2004-01-01 18:14:00 2004-01-01 18:14:00  0 days 00:00:00

# %%
# Extracting only minute components from the new derived column
train_df['FlightDelayin_min'] = train_df['FlightDelayinmin'].dt.components['minutes']

# %%
train_df.head()
# Out:
#     FlightNumber  Year Month DayofMonth  DayOfWeek  ScheduledDepTime  \
# 0  SMF_ATL_37955  2004    01         01          4              1150
# 1  VLD_ATL_48545  2004    01         01          4              1329
# 2  DTW_BOS_31626  2004    01         01          4              1507
# 3  MKE_BWI_39603  2004    01         01          4              1240
# 4  DFW_CLT_33648  2004    01         01          4              1456
#
#   ScheduledArrTime  ScheduledTravelTime Origin Destination  Distance  \
# 0             1911                  261    SMF         ATL      2092
# 1             1455                   86    VLD         ATL       208
# 2             1657                  110    DTW         BOS       632
# 3             1525                  105    MKE         BWI       641
# 4             1814                  138    DFW         CLT       936
#
#   ActualArrivalTimeStamp  ScheduledArrTime_c FlightDelayinmin  \
# 0    2004-01-01 19:11:00 2004-01-01 19:11:00  0 days 00:00:00
# 1    2004-01-01 14:55:00 2004-01-01 14:55:00  0 days 00:00:00
# 2    2004-01-01 18:33:00 2004-01-01 16:57:00  0 days 01:36:00
# 3    2004-01-01 15:25:00 2004-01-01 15:25:00  0 days 00:00:00
# 4    2004-01-01 18:14:00 2004-01-01 18:14:00  0 days 00:00:00
#
#    FlightDelayin_min
# 0                  0
# 1                  0
# 2                 36
# 3                  0
# 4                  0

# %%
# Extracting only hour components from the new derived column
train_df['FlightDelayin_hour'] = train_df['FlightDelayinmin'].dt.components['hours']

# %%
train_df.head()
# Out:
#     FlightNumber  Year Month DayofMonth  DayOfWeek  ScheduledDepTime  \
# 0  SMF_ATL_37955  2004    01         01          4              1150
# 1  VLD_ATL_48545  2004    01         01          4              1329
# 2  DTW_BOS_31626  2004    01         01          4              1507
# 3  MKE_BWI_39603  2004    01         01          4              1240
# 4  DFW_CLT_33648  2004    01         01          4              1456
#
#   ScheduledArrTime  ScheduledTravelTime Origin Destination  Distance  \
# 0             1911                  261    SMF         ATL      2092
# 1             1455                   86    VLD         ATL       208
# 2             1657                  110    DTW         BOS       632
# 3             1525                  105    MKE         BWI       641
# 4             1814                  138    DFW         CLT       936
#
#   ActualArrivalTimeStamp  ScheduledArrTime_c FlightDelayinmin  \
# 0    2004-01-01 19:11:00 2004-01-01 19:11:00  0 days 00:00:00
# 1    2004-01-01 14:55:00 2004-01-01 14:55:00  0 days 00:00:00
# 2    2004-01-01 18:33:00 2004-01-01 16:57:00  0 days 01:36:00
# 3    2004-01-01 15:25:00 2004-01-01 15:25:00  0 days 00:00:00
# 4    2004-01-01 18:14:00 2004-01-01 18:14:00  0 days 00:00:00
#
#    FlightDelayin_min  FlightDelayin_hour
# 0                  0                   0
# 1                  0                   0
# 2                 36                   1
# 3                  0                   0
# 4                  0                   0

# %%
train_df.dtypes
# Out:
# FlightNumber                       object
# Year                                int64
# Month                              object
# DayofMonth                         object
# DayOfWeek                           int64
# ScheduledDepTime                    int64
# ScheduledArrTime                   object
# ScheduledTravelTime                 int64
# Origin                             object
# Destination                        object
# Distance                            int64
# ActualArrivalTimeStamp     datetime64[ns]
# ScheduledArrTime_c         datetime64[ns]
# FlightDelayinmin          timedelta64[ns]
# FlightDelayin_min                   int64
# FlightDelayin_hour                  int64
# dtype: object

# %%
# multiplying hour component column by 60 to obtain total hours in minutes
train_df['FlightDelayin_hour'] = train_df['FlightDelayin_hour'] * 60

# %%
train_df.head()
# Out:
#     FlightNumber  Year Month DayofMonth  DayOfWeek  ScheduledDepTime  \
# 0  SMF_ATL_37955  2004    01         01          4              1150
# 1  VLD_ATL_48545  2004    01         01          4              1329
# 2  DTW_BOS_31626  2004    01         01          4              1507
# 3  MKE_BWI_39603  2004    01         01          4              1240
# 4  DFW_CLT_33648  2004    01         01          4              1456
#
#   ScheduledArrTime  ScheduledTravelTime Origin Destination  Distance  \
# 0             1911                  261    SMF         ATL      2092
# 1             1455                   86    VLD         ATL       208
# 2             1657                  110    DTW         BOS       632
# 3             1525                  105    MKE         BWI       641
# 4             1814                  138    DFW         CLT       936
#
#   ActualArrivalTimeStamp  ScheduledArrTime_c FlightDelayinmin  \
# 0    2004-01-01 19:11:00 2004-01-01 19:11:00  0 days 00:00:00
# 1    2004-01-01 14:55:00 2004-01-01 14:55:00  0 days 00:00:00
# 2    2004-01-01 18:33:00 2004-01-01 16:57:00  0 days 01:36:00
# 3    2004-01-01 15:25:00 2004-01-01 15:25:00  0 days 00:00:00
# 4    2004-01-01 18:14:00 2004-01-01 18:14:00  0 days 00:00:00
#
#    FlightDelayin_min  FlightDelayin_hour
# 0                  0                   0
# 1                  0                   0
# 2                 36                  60
# 3                  0                   0
# 4                  0                   0

# %%
# Adding both hour and min column components to obtain total delay in minutes
train_df['TotalFlightDelay'] = train_df['FlightDelayin_hour'] + train_df['FlightDelayin_min']

# %%
train_df.head()
# Out:
#     FlightNumber  Year Month DayofMonth  DayOfWeek  ScheduledDepTime  \
# 0  SMF_ATL_37955  2004    01         01          4              1150
# 1  VLD_ATL_48545  2004    01         01          4              1329
# 2  DTW_BOS_31626  2004    01         01          4              1507
# 3  MKE_BWI_39603  2004    01         01          4              1240
# 4  DFW_CLT_33648  2004    01         01          4              1456
#
#   ScheduledArrTime  ScheduledTravelTime Origin Destination  Distance  \
# 0             1911                  261    SMF         ATL      2092
# 1             1455                   86    VLD         ATL       208
# 2             1657                  110    DTW         BOS       632
# 3             1525                  105    MKE         BWI       641
# 4             1814                  138    DFW         CLT       936
#
#   ActualArrivalTimeStamp  ScheduledArrTime_c FlightDelayinmin  \
# 0    2004-01-01 19:11:00 2004-01-01 19:11:00  0 days 00:00:00
# 1    2004-01-01 14:55:00 2004-01-01 14:55:00  0 days 00:00:00
# 2    2004-01-01 18:33:00 2004-01-01 16:57:00  0 days 01:36:00
# 3    2004-01-01 15:25:00 2004-01-01 15:25:00  0 days 00:00:00
# 4    2004-01-01 18:14:00 2004-01-01 18:14:00  0 days 00:00:00
#
#    FlightDelayin_min  FlightDelayin_hour  TotalFlightDelay
# 0                  0                   0                 0
# 1                  0                   0                 0
# 2                 36                  60                96
# 3                  0                   0                 0
# 4                  0                   0                 0

# %%
print(train_df['TotalFlightDelay'].unique())
print()
print(train_df['TotalFlightDelay'].max())
print(train_df['TotalFlightDelay'].min())
# Out:
# [  0  96  69 120  72 154  29  32  57  31 101 110  88 121  70  98 109  48
#   40  44 147  67  54  80  85  83 173  60  36  99 162  39  23 140  49  56
#  133 112 128 116 151 169  47  91 145 158  93  46 124 149 107  74 100 117
#   78  42  41  59  97 134 122 130  34  35 127  43  87 119  84 179  92 168
#  180 143 141 102 108  66 160 137  81 105 103 111 156 150 123  65 171  90
#   58  33 157 161 155 167  89  71  94  45 163 131 166 159 177  76  51 139
#  104 113  77 132 125 144 146  73 174 135 152  68  50 172 176 118 153 175
#  170 148  24 106  22  37  82 164  95  75 138 178  86 114 142 136  27  30
#   28  52 165 126 129 115  21  79  55  26  53]
#
# 180
# 0

# %%
print(train_df['TotalFlightDelay'].sort_values())
# Out:
# 0         0
# 4658      0
# 4657      0
# 4656      0
# 4655      0
#        ...
# 3675    180
# 5583    180
# 5431    180
# 7844    180
# 7086    180
# Name: TotalFlightDelay, Length: 7861, dtype: int64

# %%
# Binninig to obtain final target column from total minutes

bins = [-1,15]
names = ['2','1']

d = dict(enumerate(names, 1))

train_df['FlightDelayStatus'] = np.vectorize(d.get)(np.digitize(train_df['FlightDelayinmin'], bins))

# %%
train_df.head()
# Out:
#     FlightNumber  Year Month DayofMonth  DayOfWeek  ScheduledDepTime  \
# 0  SMF_ATL_37955  2004    01         01          4              1150
# 1  VLD_ATL_48545  2004    01         01          4              1329
# 2  DTW_BOS_31626  2004    01         01          4              1507
# 3  MKE_BWI_39603  2004    01         01          4              1240
# 4  DFW_CLT_33648  2004    01         01          4              1456
#
#   ScheduledArrTime  ScheduledTravelTime Origin Destination  Distance  \
# 0             1911                  261    SMF         ATL      2092
# 1             1455                   86    VLD         ATL       208
# 2             1657                  110    DTW         BOS       632
# 3             1525                  105    MKE         BWI       641
# 4             1814                  138    DFW         CLT       936
#
#   ActualArrivalTimeStamp  ScheduledArrTime_c FlightDelayinmin  \
# 0    2004-01-01 19:11:00 2004-01-01 19:11:00  0 days 00:00:00
# 1    2004-01-01 14:55:00 2004-01-01 14:55:00  0 days 00:00:00
# 2    2004-01-01 18:33:00 2004-01-01 16:57:00  0 days 01:36:00
# 3    2004-01-01 15:25:00 2004-01-01 15:25:00  0 days 00:00:00
# 4    2004-01-01 18:14:00 2004-01-01 18:14:00  0 days 00:00:00
#
#    FlightDelayin_min  FlightDelayin_hour  TotalFlightDelay FlightDelayStatus
# 0                  0                   0                 0                 2
# 1                  0                   0                 0                 2
# 2                 36                  60                96                 1
# 3                  0                   0                 0                 2
# 4                  0                   0                 0                 2

# %%
train_df.loc[train_df['FlightDelayStatus'] == '2']
# Out:
#        FlightNumber  Year Month DayofMonth  DayOfWeek  ScheduledDepTime  \
# 0     SMF_ATL_37955  2004    01         01          4              1150
# 1     VLD_ATL_48545  2004    01         01          4              1329
# 3     MKE_BWI_39603  2004    01         01          4              1240
# 4     DFW_CLT_33648  2004    01         01          4              1456
# 5     PHL_CVG_49031  2004    01         01          4               620
# ...             ...   ...   ...        ...        ...               ...
# 7853  OAK_SAN_44227  2004    11         30          2              1040
# 7856  SFO_SLC_44569  2004    11         30          2              1115
# 7857  PHX_SMF_33953  2004    11         30          2               810
# 7858  BUR_SMF_54057  2004    11         30          2               705
# 7859  DCA_TPA_30436  2004    11         30          2               700
#
#      ScheduledArrTime  ScheduledTravelTime Origin Destination  Distance  \
# 0                1911                  261    SMF         ATL      2092
# 1                1455                   86    VLD         ATL       208
# 3                1525                  105    MKE         BWI       641
# 4                1814                  138    DFW         CLT       936
# 5                0814                  114    PHL         CVG       507
# ...               ...                  ...    ...         ...       ...
# 7853             1205                   85    OAK         SAN       446
# 7856             1357                  102    SFO         SLC       599
# 7857             0914                  124    PHX         SMF       647
# 7858             0825                   80    BUR         SMF       358
# 7859             0916                  136    DCA         TPA       814
#
#      ActualArrivalTimeStamp  ScheduledArrTime_c FlightDelayinmin  \
# 0       2004-01-01 19:11:00 2004-01-01 19:11:00           0 days
# 1       2004-01-01 14:55:00 2004-01-01 14:55:00           0 days
# 3       2004-01-01 15:25:00 2004-01-01 15:25:00           0 days
# 4       2004-01-01 18:14:00 2004-01-01 18:14:00           0 days
# 5       2004-01-01 08:14:00 2004-01-01 08:14:00           0 days
# ...                     ...                 ...              ...
# 7853    2004-11-30 12:05:00 2004-11-30 12:05:00           0 days
# 7856    2004-11-30 13:57:00 2004-11-30 13:57:00           0 days
# 7857    2004-11-30 09:14:00 2004-11-30 09:14:00           0 days
# 7858    2004-11-30 08:25:00 2004-11-30 08:25:00           0 days
# 7859    2004-11-30 09:16:00 2004-11-30 09:16:00           0 days
#
#       FlightDelayin_min  FlightDelayin_hour  TotalFlightDelay  \
# 0                     0                   0                 0
# 1                     0                   0                 0
# 3                     0                   0                 0
# 4                     0                   0                 0
# 5                     0                   0                 0
# ...                 ...                 ...               ...
# 7853                  0                   0                 0
# 7856                  0                   0                 0
# 7857                  0                   0                 0
# 7858                  0                   0                 0
# 7859                  0                   0                 0
#
#      FlightDelayStatus
# 0                    2
# 1                    2
# 3                    2
# 4                    2
# 5                    2
# ...                ...
# 7853                 2
# 7856                 2
# 7857                 2
# 7858                 2
# 7859                 2
#
# [6342 rows x 18 columns]

# %%
train_df.dtypes
# Out:
# FlightNumber                       object
# Year                                int64
# Month                              object
# DayofMonth                         object
# DayOfWeek                           int64
# ScheduledDepTime                    int64
# ScheduledArrTime                   object
# ScheduledTravelTime                 int64
# Origin                             object
# Destination                        object
# Distance                            int64
# ActualArrivalTimeStamp     datetime64[ns]
# ScheduledArrTime_c         datetime64[ns]
# FlightDelayinmin          timedelta64[ns]
# FlightDelayin_min                   int64
# FlightDelayin_hour                  int64
# TotalFlightDelay                    int64
# FlightDelayStatus                  object
# dtype: object

# %%
#converting FlightDelayStatus to category
train_df['FlightDelayStatus'] = train_df.FlightDelayStatus.astype('category')

# %%
#creating instance of labelencoder
#labelencoder = LabelEncoder()
# Assigning numerical values and storing
#train_df['FlightDelayStatus'] = labelencoder.fit_transform(train_df['FlightDelayStatus'])

# %%
train_df.head()
# Out:
#     FlightNumber  Year Month DayofMonth  DayOfWeek  ScheduledDepTime  \
# 0  SMF_ATL_37955  2004    01         01          4              1150
# 1  VLD_ATL_48545  2004    01         01          4              1329
# 2  DTW_BOS_31626  2004    01         01          4              1507
# 3  MKE_BWI_39603  2004    01         01          4              1240
# 4  DFW_CLT_33648  2004    01         01          4              1456
#
#   ScheduledArrTime  ScheduledTravelTime Origin Destination  Distance  \
# 0             1911                  261    SMF         ATL      2092
# 1             1455                   86    VLD         ATL       208
# 2             1657                  110    DTW         BOS       632
# 3             1525                  105    MKE         BWI       641
# 4             1814                  138    DFW         CLT       936
#
#   ActualArrivalTimeStamp  ScheduledArrTime_c FlightDelayinmin  \
# 0    2004-01-01 19:11:00 2004-01-01 19:11:00  0 days 00:00:00
# 1    2004-01-01 14:55:00 2004-01-01 14:55:00  0 days 00:00:00
# 2    2004-01-01 18:33:00 2004-01-01 16:57:00  0 days 01:36:00
# 3    2004-01-01 15:25:00 2004-01-01 15:25:00  0 days 00:00:00
# 4    2004-01-01 18:14:00 2004-01-01 18:14:00  0 days 00:00:00
#
#    FlightDelayin_min  FlightDelayin_hour  TotalFlightDelay FlightDelayStatus
# 0                  0                   0                 0                 2
# 1                  0                   0                 0                 2
# 2                 36                  60                96                 1
# 3                  0                   0                 0                 2
# 4                  0                   0                 0                 2

# %%
train_df.dtypes
# Out:
# FlightNumber                       object
# Year                                int64
# Month                              object
# DayofMonth                         object
# DayOfWeek                           int64
# ScheduledDepTime                    int64
# ScheduledArrTime                   object
# ScheduledTravelTime                 int64
# Origin                             object
# Destination                        object
# Distance                            int64
# ActualArrivalTimeStamp     datetime64[ns]
# ScheduledArrTime_c         datetime64[ns]
# FlightDelayinmin          timedelta64[ns]
# FlightDelayin_min                   int64
# FlightDelayin_hour                  int64
# TotalFlightDelay                    int64
# FlightDelayStatus                category
# dtype: object

# %%
# Dropping dervied columns 
train_df.drop(['FlightDelayinmin','FlightDelayin_min','FlightDelayin_hour','TotalFlightDelay'], axis = 1,inplace = True)

# %%
# Dropping columns after used for deriving new coluumn (ScheduledArrTime_c)
train_df.drop(['Year','Month','DayofMonth','ScheduledArrTime','ScheduledDepTime'], axis = 1,inplace = True)

# %%
train_df.head()
# Out:
#     FlightNumber  DayOfWeek  ScheduledTravelTime Origin Destination  Distance  \
# 0  SMF_ATL_37955          4                  261    SMF         ATL      2092
# 1  VLD_ATL_48545          4                   86    VLD         ATL       208
# 2  DTW_BOS_31626          4                  110    DTW         BOS       632
# 3  MKE_BWI_39603          4                  105    MKE         BWI       641
# 4  DFW_CLT_33648          4                  138    DFW         CLT       936
#
#   ActualArrivalTimeStamp  ScheduledArrTime_c FlightDelayStatus
# 0    2004-01-01 19:11:00 2004-01-01 19:11:00                 2
# 1    2004-01-01 14:55:00 2004-01-01 14:55:00                 2
# 2    2004-01-01 18:33:00 2004-01-01 16:57:00                 1
# 3    2004-01-01 15:25:00 2004-01-01 15:25:00                 2
# 4    2004-01-01 18:14:00 2004-01-01 18:14:00                 2

# %%
# Correlation plot for train data frame
corr = train_df.corr()
corr.style.background_gradient(cmap='Spectral').set_precision(2)
# Out:
# C:\Users\user\AppData\Local\Temp/ipykernel_6576/3478782214.py:2: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   corr.style.background_gradient(cmap='Spectral').set_precision(2)
# <style type="text/css">
# #T_80278_row0_col0, #T_80278_row1_col1, #T_80278_row2_col2 {
#   background-color: #5e4fa2;
#   color: #f1f1f1;
# }
# #T_80278_row0_col1, #T_80278_row0_col2, #T_80278_row1_col0, #T_80278_row2_col0 {
#   background-color: #9e0142;
#   color: #f1f1f1;
# }
# #T_80278_row1_col2, #T_80278_row2_col1 {
#   background-color: #5758a6;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_80278_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >DayOfWeek</th>
#       <th class="col_heading level0 col1" >ScheduledTravelTime</th>
#       <th class="col_heading level0 col2" >Distance</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_80278_level0_row0" class="row_heading level0 row0" >DayOfWeek</th>
#       <td id="T_80278_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_80278_row0_col1" class="data row0 col1" >0.03</td>
#       <td id="T_80278_row0_col2" class="data row0 col2" >0.03</td>
#     </tr>
#     <tr>
#       <th id="T_80278_level0_row1" class="row_heading level0 row1" >ScheduledTravelTime</th>
#       <td id="T_80278_row1_col0" class="data row1 col0" >0.03</td>
#       <td id="T_80278_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_80278_row1_col2" class="data row1 col2" >0.98</td>
#     </tr>
#     <tr>
#       <th id="T_80278_level0_row2" class="row_heading level0 row2" >Distance</th>
#       <td id="T_80278_row2_col0" class="data row2 col0" >0.03</td>
#       <td id="T_80278_row2_col1" class="data row2 col1" >0.98</td>
#       <td id="T_80278_row2_col2" class="data row2 col2" >1.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
train_df_v1 = train_df.drop(['ScheduledTravelTime'], axis = 1)

# %%
train_df_v1.shape
# Out:
# (7861, 8)

# %%
train_df_v1.head()
# Out:
#     FlightNumber  DayOfWeek Origin Destination  Distance  \
# 0  SMF_ATL_37955          4    SMF         ATL      2092
# 1  VLD_ATL_48545          4    VLD         ATL       208
# 2  DTW_BOS_31626          4    DTW         BOS       632
# 3  MKE_BWI_39603          4    MKE         BWI       641
# 4  DFW_CLT_33648          4    DFW         CLT       936
#
#   ActualArrivalTimeStamp  ScheduledArrTime_c FlightDelayStatus
# 0    2004-01-01 19:11:00 2004-01-01 19:11:00                 2
# 1    2004-01-01 14:55:00 2004-01-01 14:55:00                 2
# 2    2004-01-01 18:33:00 2004-01-01 16:57:00                 1
# 3    2004-01-01 15:25:00 2004-01-01 15:25:00                 2
# 4    2004-01-01 18:14:00 2004-01-01 18:14:00                 2

# %%
train_df_v1.loc[train_df_v1['DayOfWeek'] == 1]
# Out:
#        FlightNumber  DayOfWeek Origin Destination  Distance  \
# 230   BTR_ATL_37937          1    BTR         ATL       449
# 231   BTR_ATL_35648          1    BTR         ATL       449
# 232   RSW_BOS_42049          1    RSW         BOS      1249
# 233   DCA_BOS_49472          1    DCA         BOS       399
# 234   FAI_BRW_28361          1    FAI         BRW       503
# ...             ...        ...    ...         ...       ...
# 7799  BNA_SAT_36670          1    BNA         SAT       822
# 7800  SEA_SJC_48582          1    SEA         SJC       697
# 7801  GJT_SLC_48677          1    GJT         SLC       217
# 7802  HOU_STL_55270          1    HOU         STL       687
# 7803  DFW_XNA_32165          1    DFW         XNA       281
#
#      ActualArrivalTimeStamp  ScheduledArrTime_c FlightDelayStatus
# 230     2004-03-01 08:45:00 2004-03-01 08:45:00                 2
# 231     2004-03-01 10:00:00 2004-03-01 10:00:00                 2
# 232     2004-03-01 14:27:00 2004-03-01 14:27:00                 2
# 233     2004-03-01 15:53:00 2004-03-01 15:53:00                 2
# 234     2004-03-01 17:54:00 2004-03-01 17:54:00                 2
# ...                     ...                 ...               ...
# 7799    2004-11-29 11:50:00 2004-11-29 11:50:00                 2
# 7800    2004-11-29 12:09:00 2004-11-29 12:09:00                 2
# 7801    2004-11-29 07:42:00 2004-11-29 07:42:00                 2
# 7802    2004-11-29 12:15:00 2004-11-29 11:40:00                 1
# 7803    2004-11-29 20:34:00 2004-11-29 19:08:00                 1
#
# [1141 rows x 8 columns]

# %%
#creating instance of labelencoder
labelencoder = LabelEncoder()
# Assigning numerical values and storing
train_df_v1['DayOfWeek'] = labelencoder.fit_transform(train_df_v1['DayOfWeek'])

# %%
train_df_v1['FlightDelayStatus'] = train_df_v1.FlightDelayStatus.astype(int)

# %%
train_df_v1['FlightDelayStatus'] = train_df_v1.FlightDelayStatus.astype('category')

# %%
train_df_v1.dtypes
# Out:
# FlightNumber                      object
# DayOfWeek                          int64
# Origin                            object
# Destination                       object
# Distance                           int64
# ActualArrivalTimeStamp    datetime64[ns]
# ScheduledArrTime_c        datetime64[ns]
# FlightDelayStatus               category
# dtype: object

# %%
train_df_v1.loc[train_df_v1['FlightDelayStatus'] == 1]
# Out:
#        FlightNumber  DayOfWeek Origin Destination  Distance  \
# 2     DTW_BOS_31626          3    DTW         BOS       632
# 6     DTW_DCA_46311          3    DTW         DCA       405
# 8     CLL_DFW_31275          3    CLL         DFW       164
# 10    DEN_GJT_26718          3    DEN         GJT       212
# 11    SFO_HNL_29125          3    SFO         HNL      2398
# ...             ...        ...    ...         ...       ...
# 7849  GEG_PHX_40327          1    GEG         PHX      1020
# 7852  ORD_PVD_51672          1    ORD         PVD       849
# 7854  ATL_SBN_43428          1    ATL         SBN       566
# 7855  IAD_SDF_42429          1    IAD         SDF       451
# 7860  ATL_XNA_35971          1    ATL         XNA       589
#
#      ActualArrivalTimeStamp  ScheduledArrTime_c FlightDelayStatus
# 2       2004-01-01 18:33:00 2004-01-01 16:57:00                 1
# 6       2004-01-01 16:18:00 2004-01-01 15:09:00                 1
# 8       2004-01-01 17:30:00 2004-01-01 15:30:00                 1
# 10      2004-01-01 13:35:00 2004-01-01 12:23:00                 1
# 11      2004-01-01 17:58:00 2004-01-01 15:24:00                 1
# ...                     ...                 ...               ...
# 7849    2004-11-30 14:38:00 2004-11-30 11:58:00                 1
# 7852    2004-11-30 23:25:00 2004-11-30 20:48:00                 1
# 7854    2004-11-30 21:39:00 2004-11-30 18:48:00                 1
# 7855    2004-11-30 09:53:00 2004-11-30 09:29:00                 1
# 7860    2004-11-30 20:44:00 2004-11-30 17:55:00                 1
#
# [1519 rows x 8 columns]

# %%
train_df_v1.loc[train_df_v1['DayOfWeek'] == 0]
# Out:
#        FlightNumber  DayOfWeek Origin Destination  Distance  \
# 230   BTR_ATL_37937          0    BTR         ATL       449
# 231   BTR_ATL_35648          0    BTR         ATL       449
# 232   RSW_BOS_42049          0    RSW         BOS      1249
# 233   DCA_BOS_49472          0    DCA         BOS       399
# 234   FAI_BRW_28361          0    FAI         BRW       503
# ...             ...        ...    ...         ...       ...
# 7799  BNA_SAT_36670          0    BNA         SAT       822
# 7800  SEA_SJC_48582          0    SEA         SJC       697
# 7801  GJT_SLC_48677          0    GJT         SLC       217
# 7802  HOU_STL_55270          0    HOU         STL       687
# 7803  DFW_XNA_32165          0    DFW         XNA       281
#
#      ActualArrivalTimeStamp  ScheduledArrTime_c FlightDelayStatus
# 230     2004-03-01 08:45:00 2004-03-01 08:45:00                 2
# 231     2004-03-01 10:00:00 2004-03-01 10:00:00                 2
# 232     2004-03-01 14:27:00 2004-03-01 14:27:00                 2
# 233     2004-03-01 15:53:00 2004-03-01 15:53:00                 2
# 234     2004-03-01 17:54:00 2004-03-01 17:54:00                 2
# ...                     ...                 ...               ...
# 7799    2004-11-29 11:50:00 2004-11-29 11:50:00                 2
# 7800    2004-11-29 12:09:00 2004-11-29 12:09:00                 2
# 7801    2004-11-29 07:42:00 2004-11-29 07:42:00                 2
# 7802    2004-11-29 12:15:00 2004-11-29 11:40:00                 1
# 7803    2004-11-29 20:34:00 2004-11-29 19:08:00                 1
#
# [1141 rows x 8 columns]

# %%
train_df_v1.nunique()
# Out:
# FlightNumber              7861
# DayOfWeek                    7
# Origin                     223
# Destination                215
# Distance                   984
# ActualArrivalTimeStamp    7594
# ScheduledArrTime_c        7562
# FlightDelayStatus            2
# dtype: int64

# %%
train_df_v1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7861 entries, 0 to 7860
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   FlightNumber            7861 non-null   object
#  1   DayOfWeek               7861 non-null   int64
#  2   Origin                  7861 non-null   object
#  3   Destination             7861 non-null   object
#  4   Distance                7861 non-null   int64
#  5   ActualArrivalTimeStamp  7861 non-null   datetime64[ns]
#  6   ScheduledArrTime_c      7861 non-null   datetime64[ns]
#  7   FlightDelayStatus       7861 non-null   category
# dtypes: category(1), datetime64[ns](2), int64(2), object(3)
# memory usage: 437.8+ KB

# %%
#train_df.to_csv('train_target')

# %%
#Saving the dataset as csv format
train_df_v1.to_csv('train_target.csv',index_label = False)
